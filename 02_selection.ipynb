# %% [markdown]
# # 2 Selecting from dataframe

# %%
import pandas as pd

df=pd.read_csv("house_prices_dataset/train.csv")

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# ## 2.1 Selecting columns

# %%
df.Fence
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 1455      NaN
# 1456    MnPrv
# 1457    GdPrv
# 1458      NaN
# 1459      NaN
# Name: Fence, Length: 1460, dtype: object

# %%
df['Fence'] # returns a pandas Series
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 1455      NaN
# 1456    MnPrv
# 1457    GdPrv
# 1458      NaN
# 1459      NaN
# Name: Fence, Length: 1460, dtype: object

# %%
df[['LotShape', 'LandContour']] # returns a df columns dont need to be consecutive in original
# Out:
#      LotShape LandContour
# 0         Reg         Lvl
# 1         Reg         Lvl
# 2         IR1         Lvl
# 3         IR1         Lvl
# 4         IR1         Lvl
# ...       ...         ...
# 1455      Reg         Lvl
# 1456      Reg         Lvl
# 1457      Reg         Lvl
# 1458      Reg         Lvl
# 1459      Reg         Lvl
#
# [1460 rows x 2 columns]

# %% [markdown]
# ## 2.2 Selecting rows
# ### 2.2.1 Conditions

# %%
df.SalePrice > 181500 # returns a bool series
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1455    False
# 1456     True
# 1457     True
# 1458    False
# 1459    False
# Name: SalePrice, Length: 1460, dtype: bool

# %%
df[df.SalePrice > 181500]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
#
# ...

# %%
df[(df.SalePrice < 210000) & (df.SalePrice > 181500)] # Chaning conditions in bool series. Beware the round brackets
# (df.SalePrice < 210000) and (df.SalePrice > 181500) This is error or when using and or not
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 28      29          20       RL         47.0    16321   Pave   NaN      IR1
# 57      58          60       RL         89.0    11645   Pave   NaN      IR1
# 62      63         120       RL         44.0     6442   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1430  1431          60       RL         60.0    21930   Pave   NaN      IR3
# 1433  1434          60       RL         93.0    10261   Pave   NaN      IR1
# 1439  1440          60       RL         80.0    11584   Pave   NaN      Reg
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
#
# ...

# %%
df[(df.SalePrice < 210000) | (df.SalePrice > 181500)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df[~((df.SalePrice < 210000) & (df.SalePrice > 181500))] # The negation
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df[df.SalePrice.isin([181500, 210000])] # You can name the values
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 216    217          20       RL         65.0     8450   Pave   NaN      Reg
# 444    445          60       RL         70.0     8750   Pave   NaN      Reg
# 453    454          60       FV         75.0     9000   Pave   NaN      Reg
# 546    547          50       RL         70.0     8737   Pave   NaN      IR1
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 216          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 444          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 453          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %% [markdown]
# ### 2.2.2 Specific delections in conditions

# %%
df.loc[(df.SalePrice < 210000) | (df.SalePrice > 181500), "MSSubClass"]
# Out:
# 0       60
# 1       20
# 2       60
# 3       70
# 4       60
#         ..
# 1455    60
# 1456    20
# 1457    70
# 1458    20
# 1459    20
# Name: MSSubClass, Length: 1460, dtype: int64

# %%
df.iloc[2:4,5:10] # Selection based on the index
# Out:
#   Street Alley LotShape LandContour Utilities
# 2   Pave   NaN      IR1         Lvl    AllPub
# 3   Pave   NaN      IR1         Lvl    AllPub

# %%
df.iloc[2:4,:] # reffering to all values
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
#
# [2 rows x 81 columns]

# %% [markdown]
# ## 2.3 Little word about indexes
# After selecting a portion of original dataframe the index preserves the original numbering

# %%
df=pd.read_csv("house_prices_dataset/train.csv")
df[df.SalePrice.isin([181500, 210000])]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 216    217          20       RL         65.0     8450   Pave   NaN      Reg
# 444    445          60       RL         70.0     8750   Pave   NaN      Reg
# 453    454          60       FV         75.0     9000   Pave   NaN      Reg
# 546    547          50       RL         70.0     8737   Pave   NaN      IR1
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 216          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 444          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 453          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %% [markdown]
# In pandas everything can be an index, but most commonly:
# - numbers
# - strings or chars
# - dates
# - timestamps
